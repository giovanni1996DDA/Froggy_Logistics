-- %% [markdown]
-- # [ServicesDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ServicesDB]    Script Date: 27/10/2024 13:01:38 ******/
CREATE DATABASE [ServicesDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ServicesDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\ServicesDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ServicesDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\ServicesDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ServicesDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ServicesDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ServicesDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ServicesDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ServicesDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ServicesDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ServicesDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [ServicesDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ServicesDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ServicesDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ServicesDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ServicesDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ServicesDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ServicesDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ServicesDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ServicesDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ServicesDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ServicesDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ServicesDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ServicesDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ServicesDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ServicesDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ServicesDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ServicesDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ServicesDB] SET RECOVERY FULL 
GO
ALTER DATABASE [ServicesDB] SET  MULTI_USER 
GO
ALTER DATABASE [ServicesDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ServicesDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ServicesDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ServicesDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ServicesDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ServicesDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ServicesDB', N'ON'
GO
ALTER DATABASE [ServicesDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [ServicesDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Permiso]

-- %%
USE [ServicesDB]
GO

-- %%
/****** Object:  Table [dbo].[Permiso]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Permiso](
	[Id] [uniqueidentifier] NOT NULL,
	[Nombre] [nvarchar](255) NOT NULL,
	[Modulo] [int] NOT NULL,
	[TipoPermiso] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
/****** Object:  Table [dbo].[Rol]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rol](
	[Id] [uniqueidentifier] NOT NULL,
	[Nombre] [nvarchar](255) NOT NULL,
	[Descripcion] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RolPermisoRelation]

-- %%
/****** Object:  Table [dbo].[RolPermisoRelation]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RolPermisoRelation](
	[IdRol] [uniqueidentifier] NOT NULL,
	[IdPermiso] [uniqueidentifier] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdRol] ASC,
	[IdPermiso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RolRolRelation]

-- %%
/****** Object:  Table [dbo].[RolRolRelation]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RolRolRelation](
	[FatherId] [uniqueidentifier] NOT NULL,
	[ChildId] [uniqueidentifier] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[FatherId] ASC,
	[ChildId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Screen]

-- %%
/****** Object:  Table [dbo].[Screen]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Screen](
	[OptionName] [varchar](50) NULL,
	[ScreenName] [varchar](50) NULL,
	[Acceso] [uniqueidentifier] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[Id] [uniqueidentifier] NOT NULL,
	[UserName] [nvarchar](255) NOT NULL,
	[Password] [nvarchar](255) NOT NULL,
	[Nombre] [nvarchar](255) NULL,
	[Apellido] [nvarchar](255) NULL,
	[Email] [nvarchar](255) NULL,
	[EspecialidadId] [uniqueidentifier] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserPermisoRelation]

-- %%
/****** Object:  Table [dbo].[UserPermisoRelation]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserPermisoRelation](
	[IdUser] [uniqueidentifier] NOT NULL,
	[IdPermiso] [uniqueidentifier] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUser] ASC,
	[IdPermiso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserRolRelation]

-- %%
/****** Object:  Table [dbo].[UserRolRelation]    Script Date: 27/10/2024 13:01:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserRolRelation](
	[IdUser] [uniqueidentifier] NOT NULL,
	[IdRol] [uniqueidentifier] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUser] ASC,
	[IdRol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Permiso]

-- %%
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'fd340d40-1c43-4a5f-9a69-0baae555e066', N'Crear Paciente', 1, 0)
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'93331deb-15d4-4612-b4c0-1bfae475fe10', N'Crear Rol/Permiso', 2, 0)
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'9e8b3b57-283b-4a5b-9f32-2d54a83ac1e3', N'Eliminar Rol/Permiso', 2, 3)
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'7a85ecb4-438a-4f4e-be88-34e51dd474cd', N'Visualizar Paciente', 1, 1)
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'09f00639-f178-442e-b61a-4dc73c027185', N'Modificar Paciente', 1, 2)
INSERT [dbo].[Permiso] ([Id], [Nombre], [Modulo], [TipoPermiso]) VALUES (N'c8d8e5b9-29df-41e5-93d2-8f09cc2ab972', N'Modificar Rol/Permiso', 2, 2)
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
INSERT [dbo].[Rol] ([Id], [Nombre], [Descripcion]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'Admin', N'Admin')
INSERT [dbo].[Rol] ([Id], [Nombre], [Descripcion]) VALUES (N'a57357d4-f6fb-4964-a6fe-9080c62256d5', N'Recepcion', N'Recepcion')
GO

-- %% [markdown]
-- # [dbo].[RolPermisoRelation]

-- %%
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'93331deb-15d4-4612-b4c0-1bfae475fe10')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'9e8b3b57-283b-4a5b-9f32-2d54a83ac1e3')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'7a85ecb4-438a-4f4e-be88-34e51dd474cd')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'09f00639-f178-442e-b61a-4dc73c027185')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'c8d8e5b9-29df-41e5-93d2-8f09cc2ab972')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'a57357d4-f6fb-4964-a6fe-9080c62256d5', N'fd340d40-1c43-4a5f-9a69-0baae555e066')
INSERT [dbo].[RolPermisoRelation] ([IdRol], [IdPermiso]) VALUES (N'a57357d4-f6fb-4964-a6fe-9080c62256d5', N'09f00639-f178-442e-b61a-4dc73c027185')
GO

-- %% [markdown]
-- # [dbo].[RolRolRelation]

-- %%
INSERT [dbo].[RolRolRelation] ([FatherId], [ChildId]) VALUES (N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c', N'a57357d4-f6fb-4964-a6fe-9080c62256d5')
GO

-- %% [markdown]
-- # [dbo].[Screen]

-- %%
INSERT [dbo].[Screen] ([OptionName], [ScreenName], [Acceso]) VALUES (N'Modificar Paciente', N'ModifyPaciente', N'09f00639-f178-442e-b61a-4dc73c027185')
INSERT [dbo].[Screen] ([OptionName], [ScreenName], [Acceso]) VALUES (N'Visualizar Paciente', N'VisualizePaciente', N'7a85ecb4-438a-4f4e-be88-34e51dd474cd')
INSERT [dbo].[Screen] ([OptionName], [ScreenName], [Acceso]) VALUES (N'Pacientes', N'Pacientes', N'a57357d4-f6fb-4964-a6fe-9080c62256d5')
INSERT [dbo].[Screen] ([OptionName], [ScreenName], [Acceso]) VALUES (N'Parametrizaciones', N'Parametrizaciones', N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c')
INSERT [dbo].[Screen] ([OptionName], [ScreenName], [Acceso]) VALUES (N'Crear Paciente', N'CreatePaciente', N'fd340d40-1c43-4a5f-9a69-0baae555e066')
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
INSERT [dbo].[User] ([Id], [UserName], [Password], [Nombre], [Apellido], [Email], [EspecialidadId]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'a', N'a', N'juan', N'diaz', N'pito@hotmail.com', N'73b1de97-ecc8-4468-9b9d-2e54c7cb1f0d')
GO

-- %% [markdown]
-- # [dbo].[UserPermisoRelation]

-- %%
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'fd340d40-1c43-4a5f-9a69-0baae555e066')
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'93331deb-15d4-4612-b4c0-1bfae475fe10')
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'9e8b3b57-283b-4a5b-9f32-2d54a83ac1e3')
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'7a85ecb4-438a-4f4e-be88-34e51dd474cd')
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'09f00639-f178-442e-b61a-4dc73c027185')
INSERT [dbo].[UserPermisoRelation] ([IdUser], [IdPermiso]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'c8d8e5b9-29df-41e5-93d2-8f09cc2ab972')
GO

-- %% [markdown]
-- # [dbo].[UserRolRelation]

-- %%
INSERT [dbo].[UserRolRelation] ([IdUser], [IdRol]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'b0f2fd80-fdd5-420c-be6f-2882ab39c48c')
INSERT [dbo].[UserRolRelation] ([IdUser], [IdRol]) VALUES (N'11e4dce6-5e93-4b33-94b5-041ae51627b8', N'a57357d4-f6fb-4964-a6fe-9080c62256d5')
GO

-- %% [markdown]
-- # [IX_Permiso_Modulo_TipoPermiso]

-- %%
/****** Object:  Index [IX_Permiso_Modulo_TipoPermiso]    Script Date: 27/10/2024 13:01:38 ******/
CREATE UNIQUE NONCLUSTERED INDEX [IX_Permiso_Modulo_TipoPermiso] ON [dbo].[Permiso]
(
	[Modulo] ASC,
	[TipoPermiso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, DROP_EXISTING = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__RolPermis__IdPer__10566F31]

-- %%
ALTER TABLE [dbo].[RolPermisoRelation]  WITH CHECK ADD FOREIGN KEY([IdPermiso])
REFERENCES [dbo].[Permiso] ([Id])
GO

-- %% [markdown]
-- # [FK__RolPermis__IdRol__114A936A]

-- %%
ALTER TABLE [dbo].[RolPermisoRelation]  WITH CHECK ADD FOREIGN KEY([IdRol])
REFERENCES [dbo].[Rol] ([Id])
GO

-- %% [markdown]
-- # [FK__RolRolRel__Child__123EB7A3]

-- %%
ALTER TABLE [dbo].[RolRolRelation]  WITH CHECK ADD FOREIGN KEY([ChildId])
REFERENCES [dbo].[Rol] ([Id])
GO

-- %% [markdown]
-- # [FK__RolRolRel__Fathe__1332DBDC]

-- %%
ALTER TABLE [dbo].[RolRolRelation]  WITH CHECK ADD FOREIGN KEY([FatherId])
REFERENCES [dbo].[Rol] ([Id])
GO

-- %% [markdown]
-- # [FK__UserPermi__IdPer__14270015]

-- %%
ALTER TABLE [dbo].[UserPermisoRelation]  WITH CHECK ADD FOREIGN KEY([IdPermiso])
REFERENCES [dbo].[Permiso] ([Id])
GO

-- %% [markdown]
-- # [FK__UserPermi__IdUse__151B244E]

-- %%
ALTER TABLE [dbo].[UserPermisoRelation]  WITH CHECK ADD FOREIGN KEY([IdUser])
REFERENCES [dbo].[User] ([Id])
GO

-- %% [markdown]
-- # [FK__UserRolRe__IdRol__160F4887]

-- %%
ALTER TABLE [dbo].[UserRolRelation]  WITH CHECK ADD FOREIGN KEY([IdRol])
REFERENCES [dbo].[Rol] ([Id])
GO

-- %% [markdown]
-- # [FK__UserRolRe__IdUse__17036CC0]

-- %%
ALTER TABLE [dbo].[UserRolRelation]  WITH CHECK ADD FOREIGN KEY([IdUser])
REFERENCES [dbo].[User] ([Id])
GO

-- %% [markdown]
-- # [ServicesDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ServicesDB] SET  READ_WRITE 
GO
